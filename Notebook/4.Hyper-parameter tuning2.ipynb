# %%
import pandas as pd
from keras.layers import Input, LSTM, Dense, Concatenate
from keras.models import Model
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

###plot
import numpy as np
import matplotlib.pyplot as plt

# %%
Train = pd.read_csv('WAL_MODEL_Train.csv')
Test = pd.read_csv('WAL_MODEL_Test.csv')
Valid = pd.read_csv('WAL_MODEL_Valid.csv')
COST_data = pd.read_csv('COST.csv')
KO_data = pd.read_csv('KO.csv')
PEP_data = pd.read_csv('PEP.csv')
PG_data = pd.read_csv('PG.csv')
NSRGY_data = pd.read_csv('NSRGY.csv')

# %%
df = pd.concat([Train,Test,Valid],ignore_index=True)
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')

# %%
for all_date in [COST_data, KO_data, PEP_data, PG_data, NSRGY_data]:
    all_date['Date'] = pd.to_datetime(all_date['Date'], format='%d/%m/%Y %H:%M:%S').dt.date

# %%
print(['COST', 'KO', 'PEP', 'PG', 'NSRGY']+df.columns[1:].to_list())
# Out:
# ['COST', 'KO', 'PEP', 'PG', 'NSRGY', 'Date', 'WAL_Close', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', 'PCE', 'GDP', 'DXY_Close', 'CRE', 'CPI', 'UNRATE']

# %%
prices = pd.concat([COST_data['Close'], KO_data['Close'], PEP_data['Close'], PG_data['Close'], NSRGY_data['Close']],axis=1, ignore_index=True)
df = pd.concat([prices, df], axis=1, names=['COST', 'KO', 'PEP', 'PG', 'NSRGY']+df.columns[1:].to_list())

# %%
df = df.rename(columns={0:'COST', 1: "KO", 2: "PEP", 3:"PG", 4:'NSRGY'})

# %%
df = df.drop(labels=['Unnamed: 0'], axis=1)

# %%
### number of nan
df.isnull().sum()
# Out:
# COST           1
# KO             1
# PEP            0
# PG             0
# NSRGY         60
# Date           0
# WAL_Close      0
# 6 Mo          44
# 1 Yr          44
# 2 Yr          44
# 3 Yr          44
# 5 Yr          44
# 7 Yr          44
# 10 Yr         44
# 20 Yr         44
# PCE            0
# GDP           63
# DXY_Close    114
# CRE            2
# CPI            0
# UNRATE         0
# dtype: int64

# %%
### use pervious values
df = df.fillna(method='backfill')

# %%
df[df['Date'] < pd.to_datetime('2022-10-03')].isnull().sum()
# Out:
# COST         0
# KO           0
# PEP          0
# PG           0
# NSRGY        0
# Date         0
# WAL_Close    0
# 6 Mo         0
# 1 Yr         0
# 2 Yr         0
# 3 Yr         0
# 5 Yr         0
# 7 Yr         0
# 10 Yr        0
# 20 Yr        0
# PCE          0
# GDP          0
# DXY_Close    0
# CRE          0
# CPI          0
# UNRATE       0
# dtype: int64

# %%
df[df['Date'] < pd.to_datetime('2022-10-03')].to_csv('dataset.csv')

# %%
df_v1 = df[df['Date'] < pd.to_datetime('2022-10-03')]

# %%
df_v1['CPI'] = df_v1['CPI'].str[:3].astype(float)
# Out:
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\4047843882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1['CPI'] = df_v1['CPI'].str[:3].astype(float)

# %%
list_df_v1 = df_v1.columns

# %%
WINDOW_SIZE = 3
for col in list_df_v1:
  for i in range(WINDOW_SIZE): # Shift values for each step in WINDOW_SIZE
      df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
df_v1.head()
# Out:
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_21940\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
#     COST     KO    PEP     PG  NSRGY       Date  WAL_Close  6 Mo  1 Yr  2 Yr  \
# 0  44.50  28.13  36.88  52.93  18.35 2000-01-03      66.81  5.81  6.09  6.38
# 1  42.00  27.88  35.94  51.91  18.30 2000-01-04      64.38  5.75  6.00  6.30
# 2  42.78  28.47  35.06  50.83  18.00 2000-01-05      63.00  5.74  6.05  6.38
# 3  43.64  28.50  36.63  53.21  18.05 2000-01-06      63.69  5.69  6.03  6.35
# 4  46.50  30.31  38.50  57.53  18.75 2000-01-07      68.50  5.66  6.00  6.31
#
#    ...  DXY_Close +3  CRE +1  CRE +2  CRE +3  CPI +1  CPI +2  CPI +3  \
# 0  ...           NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  ...           NaN    1.16     NaN     NaN     0.3     NaN     NaN
# 2  ...           NaN    1.16    1.16     NaN     0.3     0.3     NaN
# 3  ...    104.889999    1.18    1.16    1.16     0.3     0.3     0.3
# 4  ...    105.440002    1.18    1.18    1.16     0.3     0.3     0.3
#
#    UNRATE +1  UNRATE +2  UNRATE +3
# 0        NaN        NaN        NaN
# 1        4.0        NaN        NaN
# 2        3.8        4.0        NaN
# 3        4.0        3.8        4.0
# 4        4.0        4.0        3.8
#
# [5 rows x 84 columns]

# %%
scaler_COST = MinMaxScaler(feature_range = (0,1))
COST = scaler_COST.fit_transform(df_v1['COST'].to_numpy().reshape(-1, 1))
scaler = MinMaxScaler(feature_range = (0,1))
KO = scaler.fit_transform(df_v1['KO'].to_numpy().reshape(-1, 1))

scaler = MinMaxScaler(feature_range = (0,1))
Yr10 = scaler.fit_transform(df_v1['10 Yr'].to_numpy().reshape(-1, 1))
scaler = MinMaxScaler(feature_range = (0,1))
DXY = scaler.fit_transform(df_v1['DXY_Close'].to_numpy().reshape(-1, 1))

scaler = MinMaxScaler(feature_range = (0,1))
CPI = scaler.fit_transform(df_v1['CPI'].to_numpy().reshape(-1, 1))
scaler = MinMaxScaler(feature_range = (0,1))
WAL = scaler.fit_transform(df_v1['WAL_Close'].to_numpy().reshape(-1, 1))

# %%
length_data = len(df_v1)     # rows that data has
split_ratio = 1           # %70 train + %30 validation
length_train = round(length_data * split_ratio)  

X_train_COST = []
y_train_COST = []

X_train_KO = []
y_train_KO = []

X_train_Yr10 = []
y_train_Yr10 = []

X_train_DXY = []
y_train_DXY = []

X_train_CPI = []
y_train_CPI = []

X_train_WAL = []
y_train_WAL = []


time_step = 14

for i in range(time_step, length_train):
    X_train_COST.append(COST[i-time_step:i])
    y_train_COST.append(COST[i])
    
    X_train_KO.append(KO[i-time_step:i])
    y_train_KO.append(KO[i])

    X_train_Yr10.append(Yr10[i-time_step:i])
    y_train_Yr10.append(Yr10[i])
    
    X_train_DXY.append(DXY[i-time_step:i])
    y_train_DXY.append(DXY[i])
    
    X_train_CPI.append(CPI[i-time_step:i])
    y_train_CPI.append(CPI[i])

    X_train_WAL.append(WAL[i-time_step:i])
    y_train_WAL.append(WAL[i])

# %%
np.array(X_train_COST).shape
# Out:
# (5711, 14, 1)

# %%
# convert list to array
num = 4000
X1_train_COST, X1_train_KO, y1_train_COST, y1_train_KO = np.array(X_train_COST[:num]),np.array(X_train_KO[:num]), np.array(y_train_COST[:num]), np.array(y_train_KO[:num])
X1_train_Yr10, X1_train_DXY, y1_train_Yr10, y1_train_DXY = np.array(X_train_Yr10[:num]),np.array(X_train_DXY[:num]), np.array(y_train_Yr10[:num]), np.array(y_train_DXY[:num])
X1_train_CPI, X1_train_WAL, y1_train_CPI, y1_train_WAL = np.array(X_train_CPI[:num]),np.array(X_train_WAL[:num]), np.array(y_train_CPI[:num]), np.array(y_train_WAL[:num])


X_test_COST, y_test_COST, X_test_KO, y_test_KO = np.array(X_train_COST[num:]), np.array(y_train_COST[num:]), np.array(X_train_KO[num:]), np.array(y_train_KO[num:])
X_test_Yr10, y_test_Yr10, X_test_DXY, y_test_DXY = np.array(X_train_Yr10[num:]), np.array(y_train_Yr10[num:]), np.array(X_train_DXY[num:]), np.array(y_train_DXY[num:])
X_test_CPI, y_test_CPI, X_test_WAL, y_test_WAL = np.array(X_train_CPI[num:]), np.array(y_train_CPI[num:]), np.array(X_train_WAL[num:]), np.array(y_train_WAL[num:])

# %%
#X_train_COST[..., np.newaxis].shape

# %%
### PLOT graph
for tar in ['COST', 'KO', 'PEP', 'PG', 'NSRGY', 'WAL_Close', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', 'PCE', 'GDP',
       'DXY_Close', 'CRE', 'CPI', 'UNRATE']:
    plt.figure()
    plt.subplots(figsize = (15,6))
    plt.plot(df_v1.Date.values, df_v1[tar].values)
    plt.xlabel("Day1 to Day4051")
    plt.ylabel("Open Price")
    plt.title(tar+' values')
    plt.show()
    
    break

# %%
def lstm_sector(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data):

    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    input2 = Input(shape=(timesteps, X_train[1].shape[-1]))
    lstm3 = LSTM(units_l1, return_sequences=True)(input2)
    lstm4 = LSTM(units_l2)(lstm3)
    

    concat = Concatenate()([lstm2, lstm4])
    dense1 = Dense(16, activation='relu')(concat)
    output = Dense(1, activation='relu')(dense1)


    model = Model(inputs=[input1, input2], outputs=output)
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = [tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

    # Train the model
    trained_model = model.fit(x=X_train, y=y_train, validation_data = (X_val_dataset, y_val_data), batch_size=16, epochs=10)

    return trained_model

def lstm_sector_c(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data, optimizer, batch_size, epoch):

    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    dense1 = Dense(25)(lstm2)
    output = Dense(1)(dense1)


    model = Model(inputs=[input1], outputs=output)
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics = [tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

    # Train the model
    model.fit(x=X_train, y=y_train, validation_data = (X_val_dataset, y_val_data), batch_size=batch_size, epochs=epoch)

    return model

# %%
learning_rate = [0.001]
batch_size = [1, 16]
epochs = [10]
model_pool = []


for lr in learning_rate:
    optimizers = [tf.keras.optimizers.legacy.Adam(lr), tf.keras.optimizers.legacy.SGD(lr), tf.keras.optimizers.legacy.RMSprop(lr)]
    #optimizers = ['adam', 'SGD']
    for bs in batch_size:
        for epoch in epochs:
            for op in optimizers:
                model_pool.append(lstm_sector_c(timesteps = time_step, units_l1=64, units_l2=64
                , X_train = X1_train_COST
                , y_train = y1_train_COST.flatten()
                , X_val_dataset=X_test_COST
                , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
                print(f'learning_rate:{lr}, Optimizer:{op}, batch_size:{bs}, epoch:{epoch}')
# Out:
# Epoch 1/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 6.6529e-05 - mean_squared_error: 6.6529e-05 - mean_absolute_error: 0.0057 - val_loss: 4.2220e-04 - val_mean_squared_error: 4.2220e-04 - val_mean_absolute_error: 0.0129
# Epoch 2/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 3.4536e-05 - mean_squared_error: 3.4536e-05 - mean_absolute_error: 0.0041 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - val_mean_absolute_error: 0.0308
# Epoch 3/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.8164e-05 - mean_squared_error: 1.8164e-05 - mean_absolute_error: 0.0032 - val_loss: 0.0014 - val_mean_squared_error: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 4/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 2.1446e-05 - mean_squared_error: 2.1446e-05 - mean_absolute_error: 0.0033 - val_loss: 4.4983e-04 - val_mean_squared_error: 4.4983e-04 - val_mean_absolute_error: 0.0133
# Epoch 5/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.5004e-05 - mean_squared_error: 1.5004e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0013 - val_mean_squared_error: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 6/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.4958e-05 - mean_squared_error: 1.4958e-05 - mean_absolute_error: 0.0027 - val_loss: 8.8653e-04 - val_mean_squared_error: 8.8653e-04 - val_mean_absolute_error: 0.0178
# Epoch 7/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.2681e-05 - mean_squared_error: 1.2681e-05 - mean_absolute_error: 0.0026 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - val_mean_absolute_error: 0.0250
# Epoch 8/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.2827e-05 - mean_squared_error: 1.2827e-05 - mean_absolute_error: 0.0026 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - val_mean_absolute_error: 0.0360
# Epoch 9/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.1550e-05 - mean_squared_error: 1.1550e-05 - mean_absolute_error: 0.0025 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - val_mean_absolute_error: 0.0360
# Epoch 10/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.0880e-05 - mean_squared_error: 1.0880e-05 - mean_absolute_error: 0.0024 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - val_mean_absolute_error: 0.0248
# learning_rate:0.001, Optimizer:<keras.optimizers.optimizer_v2.adam.Adam object at 0x000002A870F231C0>, batch_size:1, epoch:10
# Epoch 1/10
# 4000/4000 [==============================] - 16s 4ms/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0449 - val_loss: 0.1636 - val_mean_squared_error: 0.1636 - val_mean_absolute_error: 0.3495
# Epoch 2/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0421 - val_loss: 0.1443 - val_mean_squared_error: 0.1443 - val_mean_absolute_error: 0.3284
# Epoch 3/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0392 - val_loss: 0.1278 - val_mean_squared_error: 0.1278 - val_mean_absolute_error: 0.3099
# Epoch 4/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0364 - val_loss: 0.1092 - val_mean_squared_error: 0.1092 - val_mean_absolute_error: 0.2857
# Epoch 5/10
# 4000/4000 [==============================] - 14s 3ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0335 - val_loss: 0.0928 - val_mean_squared_error: 0.0928 - val_mean_absolute_error: 0.2630
# Epoch 6/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0307 - val_loss: 0.0768 - val_mean_squared_error: 0.0768 - val_mean_absolute_error: 0.2382
# Epoch 7/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0279 - val_loss: 0.0628 - val_mean_squared_error: 0.0628 - val_mean_absolute_error: 0.2145
# Epoch 8/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 9.6015e-04 - mean_squared_error: 9.6015e-04 - mean_absolute_error: 0.0251 - val_loss: 0.0537 - val_mean_squared_error: 0.0537 - val_mean_absolute_error: 0.1997
# Epoch 9/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 7.5856e-04 - mean_squared_error: 7.5856e-04 - mean_absolute_error: 0.0222 - val_loss: 0.0414 - val_mean_squared_error: 0.0414 - val_mean_absolute_error: 0.1735
# Epoch 10/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 5.8376e-04 - mean_squared_error: 5.8376e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0332 - val_mean_squared_error: 0.0332 - val_mean_absolute_error: 0.1556
# learning_rate:0.001, Optimizer:<keras.optimizers.optimizer_v2.gradient_descent.SGD object at 0x000002A870F201C0>, batch_size:1, epoch:10
# Epoch 1/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.4112e-04 - mean_squared_error: 1.4112e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - val_mean_absolute_error: 0.0656
# Epoch 2/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 5.0737e-05 - mean_squared_error: 5.0737e-05 - mean_absolute_error: 0.0053 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - val_mean_absolute_error: 0.0756
# Epoch 3/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 3.1048e-05 - mean_squared_error: 3.1048e-05 - mean_absolute_error: 0.0042 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - val_mean_absolute_error: 0.0643
# Epoch 4/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 2.2419e-05 - mean_squared_error: 2.2419e-05 - mean_absolute_error: 0.0035 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - val_mean_absolute_error: 0.0743
# Epoch 5/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 1.9141e-05 - mean_squared_error: 1.9141e-05 - mean_absolute_error: 0.0033 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - val_mean_absolute_error: 0.0636
# Epoch 6/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.7462e-05 - mean_squared_error: 1.7462e-05 - mean_absolute_error: 0.0031 - val_loss: 0.0133 - val_mean_squared_error: 0.0133 - val_mean_absolute_error: 0.0740
# Epoch 7/10
# 4000/4000 [==============================] - 14s 4ms/step - loss: 1.5893e-05 - mean_squared_error: 1.5893e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - val_mean_absolute_error: 0.0913
# Epoch 8/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.4574e-05 - mean_squared_error: 1.4574e-05 - mean_absolute_error: 0.0029 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0737
# Epoch 9/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.4328e-05 - mean_squared_error: 1.4328e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - val_mean_absolute_error: 0.0678
# Epoch 10/10
# 4000/4000 [==============================] - 15s 4ms/step - loss: 1.2898e-05 - mean_squared_error: 1.2898e-05 - mean_absolute_error: 0.0027 - val_loss: 0.0073 - val_mean_squared_error: 0.0073 - val_mean_absolute_error: 0.0522
# learning_rate:0.001, Optimizer:<keras.optimizers.optimizer_v2.rmsprop.RMSprop object at 0x000002A870F21D20>, batch_size:1, epoch:10
# Epoch 1/10
# 250/250 [==============================] - 3s 6ms/step - loss: 2.6077e-04 - mean_squared_error: 2.6077e-04 - mean_absolute_error: 0.0065 - val_loss: 6.6722e-04 - val_mean_squared_error: 6.6722e-04 - val_mean_absolute_error: 0.0152
# Epoch 2/10
# 250/250 [==============================] - 1s 4ms/step - loss: 1.1696e-05 - mean_squared_error: 1.1696e-05 - mean_absolute_error: 0.0025 - val_loss: 8.0134e-04 - val_mean_squared_error: 8.0134e-04 - val_mean_absolute_error: 0.0174
# Epoch 3/10
# 250/250 [==============================] - 1s 4ms/step - loss: 1.2443e-05 - mean_squared_error: 1.2443e-05 - mean_absolute_error: 0.0026 - val_loss: 0.0010 - val_mean_squared_error: 0.0010 - val_mean_absolute_error: 0.0206
# Epoch 4/10
# 250/250 [==============================] - 1s 4ms/step - loss: 1.1152e-05 - mean_squared_error: 1.1152e-05 - mean_absolute_error: 0.0025 - val_loss: 6.6481e-04 - val_mean_squared_error: 6.6481e-04 - val_mean_absolute_error: 0.0165
# Epoch 5/10
# 250/250 [==============================] - 1s 5ms/step - loss: 1.2155e-05 - mean_squared_error: 1.2155e-05 - mean_absolute_error: 0.0026 - val_loss: 7.5992e-04 - val_mean_squared_error: 7.5992e-04 - val_mean_absolute_error: 0.0179
# Epoch 6/10
# 250/250 [==============================] - 1s 4ms/step - loss: 9.8938e-06 - mean_squared_error: 9.8938e-06 - mean_absolute_error: 0.0023 - val_loss: 3.2103e-04 - val_mean_squared_error: 3.2103e-04 - val_mean_absolute_error: 0.0110
# Epoch 7/10
# 250/250 [==============================] - 1s 4ms/step - loss: 1.0164e-05 - mean_squared_error: 1.0164e-05 - mean_absolute_error: 0.0023 - val_loss: 3.7232e-04 - val_mean_squared_error: 3.7232e-04 - val_mean_absolute_error: 0.0121
# Epoch 8/10
# 250/250 [==============================] - 1s 5ms/step - loss: 1.0387e-05 - mean_squared_error: 1.0387e-05 - mean_absolute_error: 0.0024 - val_loss: 6.8030e-04 - val_mean_squared_error: 6.8030e-04 - val_mean_absolute_error: 0.0181
# Epoch 9/10
# 250/250 [==============================] - 1s 4ms/step - loss: 9.7475e-06 - mean_squared_error: 9.7475e-06 - mean_absolute_error: 0.0023 - val_loss: 1.8568e-04 - val_mean_squared_error: 1.8568e-04 - val_mean_absolute_error: 0.0086
# Epoch 10/10
# 250/250 [==============================] - 1s 4ms/step - loss: 1.0202e-05 - mean_squared_error: 1.0202e-05 - mean_absolute_error: 0.0024 - val_loss: 1.8620e-04 - val_mean_squared_error: 1.8620e-04 - val_mean_absolute_error: 0.0086
# learning_rate:0.001, Optimizer:<keras.optimizers.optimizer_v2.adam.Adam object at 0x000002A870F231C0>, batch_size:16, epoch:10
# Epoch 1/10
# 250/250 [==============================] - 2s 6ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - mean_absolute_error: 0.0404 - val_loss: 0.1454 - val_mean_squared_error: 0.1454 - val_mean_absolute_error: 0.3297
# Epoch 2/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0405 - val_loss: 0.1441 - val_mean_squared_error: 0.1441 - val_mean_absolute_error: 0.3284
# Epoch 3/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0402 - val_loss: 0.1424 - val_mean_squared_error: 0.1424 - val_mean_absolute_error: 0.3266
# Epoch 4/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0399 - val_loss: 0.1404 - val_mean_squared_error: 0.1404 - val_mean_absolute_error: 0.3242
# Epoch 5/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0396 - val_loss: 0.1387 - val_mean_squared_error: 0.1387 - val_mean_absolute_error: 0.3222
# Epoch 6/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0392 - val_loss: 0.1358 - val_mean_squared_error: 0.1358 - val_mean_absolute_error: 0.3184
# Epoch 7/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0391 - val_loss: 0.1347 - val_mean_squared_error: 0.1347 - val_mean_absolute_error: 0.3173
# Epoch 8/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0387 - val_loss: 0.1322 - val_mean_squared_error: 0.1322 - val_mean_absolute_error: 0.3141
# Epoch 9/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0386 - val_loss: 0.1310 - val_mean_squared_error: 0.1310 - val_mean_absolute_error: 0.3128
# Epoch 10/10
# 250/250 [==============================] - 1s 4ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0384 - val_loss: 0.1304 - val_mean_squared_error: 0.1304 - val_mean_absolute_error: 0.3125
# learning_rate:0.001, Optimizer:<keras.optimizers.optimizer_v2.gradient_descent.SGD object at 0x000002A870F201C0>, batch_size:16, epoch:10
# Epoch 1/10
# 250/250 [==============================] - 3s 6ms/step - loss: 2.6599e-04 - mean_squared_error: 2.6599e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0560
# Epoch 2/10
# 250/250 [==============================] - 1s 4ms/step - loss: 1.1793e-04 - mean_squared_error: 1.1793e-04 - mean_absolute_error: 0.0086 - val_loss: 5.0915e-04 - val_mean_squared_error: 5.0915e-04 - val_mean_absolute_error: 0.0169
# Epoch 3/10
# 250/250 [==============================] - 1s 4ms/step - loss: 9.1168e-05 - mean_squared_error: 9.1168e-05 - mean_absolute_error: 0.0078 - val_loss: 9.7033e-04 - val_mean_squared_error: 9.7033e-04 - val_mean_absolute_error: 0.0186
# Epoch 4/10
# 250/250 [==============================] - 1s 4ms/step - loss: 7.7118e-05 - mean_squared_error: 7.7118e-05 - mean_absolute_error: 0.0070 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - val_mean_absolute_error: 0.0231
# Epoch 5/10
# 250/250 [==============================] - 1s 4ms/step - loss: 6.7230e-05 - mean_squared_error: 6.7230e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0257
# Epoch 6/10
# 250/250 [==============================] - 1s 4ms/step - loss: 6.1308e-05 - mean_squared_error: 6.1308e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0410
# Epoch 7/10
# 250/250 [==============================] - 1s 5ms/step - loss: 5.5982e-05 - mean_squared_error: 5.5982e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - val_mean_absolute_error: 0.0247
# Epoch 8/10
# 250/250 [==============================] - 1s 4ms/step - loss: 5.4865e-05 - mean_squared_error: 5.4865e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0127 - val_mean_squared_error: 0.0127 - val_mean_absolute_error: 0.0892
# Epoch 9/10
# 250/250 [==============================] - 1s 4ms/step - loss: 4.8649e-05 - mean_squared_error: 4.8649e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0356
# Epoch 10/10
# 250/250 [==============================] - 1s 4ms/step - loss: 4.4161e-05 - mean_squared_error: 4.4161e-05 - mean_absolute_error: 0.0052 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - val_mean_absolute_error: 0.0309
# learning_rate:0.001, Optimizer:<keras.optimizers.optimizer_v2.rmsprop.RMSprop object at 0x000002A870F21D20>, batch_size:16, epoch:10

# %%
label_pool = []
for lr in learning_rate:
    optimizers = ['Adam', 'SGD', 'RMSprop']
    for bs in batch_size:
        for epoch in epochs:
            for op in optimizers:
                label_pool.append(op+' with batch_size : ' + str(bs)+'with learning rate: '+ str(lr))

# label_pool = []
# for opt in ['Adam', 'SGD', 'Nadam', 'RMSprop']:
#     for bs in batch_size:
#         label_pool.append(opt+' with batch_size : ' + str(bs))

plt.figure()
plt.subplots(figsize = (15,6))

for model_raw, label_ in zip(model_pool, label_pool):

    predictions = model_raw.predict(X_test_COST)
    predictions_result = scaler_COST.inverse_transform(predictions)
    y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
    rmse = (predictions_result - y_test_COST_result)/y_test_COST_result
    plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction '+ label_)

plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Open Price")
plt.title('COST prediction')
plt.show()
plt.clf()

### plt different
plt.figure()
plt.subplots(figsize = (15,6))


#plt.plot(df_v1.Date.values[num+time_step:], actual_move, label='Actual movement', color='black')
for model_raw, label_ in zip(model_pool, label_pool):
    model_raw.summary()

    predictions = model_raw.predict(X_test_COST)
    predictions_result = scaler_COST.inverse_transform(predictions)
    y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
    predictions_error = ((predictions_result - y_test_COST_result)/y_test_COST_result)*100
    X_Test_COST_result = scaler_COST.inverse_transform(X_test_COST[:,13])
    actual_move = (y_test_COST_result - X_Test_COST_result)/ X_Test_COST_result * 100

    plt.plot(df_v1.Date.values[num+time_step:], predictions_error, label='Hyper : '+ label_)

plt.plot(df_v1.Date.values[num+time_step:], actual_move, label='Actual movement', color='black')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Different between actual and prediction")
plt.legend()
plt.show()
plt.clf()
# Out:
# 54/54 [==============================] - 0s 3ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 3ms/step
# 54/54 [==============================] - 0s 2ms/step
# 54/54 [==============================] - 0s 3ms/step
# 54/54 [==============================] - 0s 3ms/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 14, 1)]           0
#
#  lstm_2 (LSTM)               (None, 14, 64)            16896
#
#  lstm_3 (LSTM)               (None, 64)                33024
#
#  dense_2 (Dense)             (None, 25)                1625
#
#  dense_3 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 51,571
# Trainable params: 51,571
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 0s 3ms/step
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 14, 1)]           0
#
#  lstm_4 (LSTM)               (None, 14, 64)            16896
#
#  lstm_5 (LSTM)               (None, 64)                33024
#
#  dense_4 (Dense)             (None, 25)                1625
#
#  dense_5 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 51,571
# Trainable params: 51,571
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 0s 3ms/step
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 14, 1)]           0
#
#  lstm_6 (LSTM)               (None, 14, 64)            16896
#
#  lstm_7 (LSTM)               (None, 64)                33024
#
#  dense_6 (Dense)             (None, 25)                1625
#
#  dense_7 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 51,571
# Trainable params: 51,571
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 0s 2ms/step
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 14, 1)]           0
#
#  lstm_8 (LSTM)               (None, 14, 64)            16896
#
#  lstm_9 (LSTM)               (None, 64)                33024
#
#  dense_8 (Dense)             (None, 25)                1625
#
#  dense_9 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 51,571
# Trainable params: 51,571
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 0s 2ms/step
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 14, 1)]           0
#
#  lstm_10 (LSTM)              (None, 14, 64)            16896
#
#  lstm_11 (LSTM)              (None, 64)                33024
#
#  dense_10 (Dense)            (None, 25)                1625
#
#  dense_11 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 51,571
# Trainable params: 51,571
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 0s 2ms/step
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 14, 1)]           0
#
#  lstm_12 (LSTM)              (None, 14, 64)            16896
#
#  lstm_13 (LSTM)              (None, 64)                33024
#
#  dense_12 (Dense)            (None, 25)                1625
#
#  dense_13 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 51,571
# Trainable params: 51,571
# Non-trainable params: 0
# _________________________________________________________________
# 54/54 [==============================] - 0s 2ms/step

# %%
print(hist.history)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(hist.history)
#
# NameError: name 'hist' is not defined

# %%
for loss in ("loss", "val_loss"):
  for model_raw, label_ in zip(model_pool, label_pool):
    plt.plot(model_raw.history[loss], label=label_, linewidth =3)

  plt.grid()
  plt.xlabel("Epochs")
  plt.ylabel({"loss": "Training loss", "val_loss": "Validation loss"}[loss])
  plt.legend(loc="upper left")
  plt.axis([0, 25, 0.00000001, 0.01])
  plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 for loss in ("loss", "val_loss"):
#       2   for model_raw, label_ in zip(model_pool, label_pool):
# ----> 3     plt.plot(model_raw.history[loss], label=label_, linewidth =3)
#       5   plt.grid()
#       6   plt.xlabel("Epochs")
#
# TypeError: 'History' object is not subscriptable

# %%
#core_model = lstm_sector_c(timesteps = time_step, units_l1=100, units_l2=100,X_train=X1_train_COST, y_train=y1_train_COST.flatten(), X_val_dataset=X_test_COST, y_val_data = y_test_COST.flatten())

# %%
#core_model.summary()

#predictions = core_model.predict(X_test_COST)
#predictions_result = scaler_COST.inverse_transform(predictions)
#y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
#X1_train_COST_result = scaler_COST.inverse_transform(X1_train_COST[:,0])
#X_Test_COST_result = scaler_COST.inverse_transform(X_test_COST[:,13])
#X1_train_COST
#rmse = (predictions_result - y_test_COST_result)/y_test_COST_result

# %%
#plt.figure()
#plt.subplots(figsize = (15,6))
#plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
#plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
#plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction')
#plt.legend()
#plt.xlabel("Time")
#plt.ylabel("Open Price")
#plt.title('COST prediction')
#plt.show()
#plt.clf()

#plt.figure()
#plt.subplots(figsize = (15,6))
#plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper')
#plt.plot(df_v1.Date.values[num+time_step:], (y_test_COST_result/X_Test_COST_result)-1, label='Actual movement')
#plt.xlabel("Time")
#plt.ylabel("Value")
#plt.title("Different between actual and prediction")
#plt.legend()
#plt.show()
#plt.clf()

# %%
#core_model = lstm_sector(timesteps = time_step, units_l1=32, units_l2=16,X_train=[X1_train_COST, 
#X1_train_KO], y_train=y1_train_COST, X_val_dataset=[X_test_COST, 
#X_test_KO], y_val_data = y_test_COST)

# %%
def lstm_sector_v1(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data, optimizer, batch_size, epoch):
    
    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    input2 = Input(shape=(timesteps, X_train[1].shape[-1]))
    lstm3 = LSTM(units_l1, return_sequences=True)(input2)
    lstm4 = LSTM(units_l2)(lstm3)
    
    input3 = Input(shape=(timesteps, X_train[2].shape[-1]))
    lstm5 = LSTM(units_l1, return_sequences=True)(input3)
    lstm6 = LSTM(units_l2)(lstm5)

    input4 = Input(shape=(timesteps, X_train[3].shape[-1]))
    lstm7 = LSTM(units_l1, return_sequences=True)(input4)
    lstm8 = LSTM(units_l2)(lstm7)

    input5 = Input(shape=(timesteps, X_train[4].shape[-1]))
    lstm9 = LSTM(units_l1, return_sequences=True)(input5)
    lstm10 = LSTM(units_l2)(lstm9)

    input6 = Input(shape=(timesteps, X_train[5].shape[-1]))
    lstm11 = LSTM(units_l1, return_sequences=True)(input6)
    lstm12 = LSTM(units_l2)(lstm11)

    concat = Concatenate()([lstm2, lstm4, lstm6, lstm8, lstm10, lstm12])
    dense1 = Dense(128, activation='relu')(concat)
    dense2 = Dense(32, activation='relu')(dense1)
    output = Dense(1, activation='relu')(dense2)


    model = Model(inputs=[input1, input2, input3, input4, input5, input6], outputs=output)
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics = [tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

    # Train the model
    model.fit(x=X_train, y=y_train, validation_data = (X_val_dataset, y_val_data), batch_size=batch_size, epochs=epoch)

    return model

# %%
learning_rate = [0.01]
batch_size = [64, 128]
epochs = [10]
model_pool = []


for lr in learning_rate:
    optimizers = [tf.keras.optimizers.legacy.Nadam(lr), tf.keras.optimizers.legacy.Adam(lr), tf.keras.optimizers.legacy.SGD(lr), tf.keras.optimizers.legacy.RMSprop(lr)]
    #optimizers = ['adam', 'SGD']
    for bs in batch_size:
        for epoch in epochs:
            for op in optimizers:
                model_pool.append(lstm_sector_c(timesteps = time_step, units_l1=64, units_l2=64
                , X_train = [X1_train_COST, X1_train_KO, X1_train_Yr10, X1_train_DXY, X1_train_CPI, X1_train_WAL]
                , y_train = y1_train_COST.flatten()
                , X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
                , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16404\2714097871.py in <module>
#      15                 , y_train = y1_train_COST.flatten()
#      16                 , X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
# ---> 17                 , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
#      18
#
# TypeError: lstm_sector_c() got an unexpected keyword argument 'optimizer'

# %%
label_pool = []
for opt in ['Adam', 'SGD', 'Nadam', 'RMSprop']:
    for bs in batch_size:
        label_pool.append(opt+' with batch_size : ' + str(bs))

# %%
label_pool
# Out:
# ['Adam with batch_size : 64',
#  'Adam with batch_size : 128',
#  'SGD with batch_size : 64',
#  'SGD with batch_size : 128',
#  'Nadam with batch_size : 64',
#  'Nadam with batch_size : 128',
#  'RMSprop with batch_size : 64',
#  'RMSprop with batch_size : 128']

# %%
label_pool = []
for opt in ['Adam', 'SGD', 'Nadam', 'RMSprop']:
    for bs in batch_size:
        label_pool.append(opt+' with batch_size : ' + str(bs))

plt.figure()
plt.subplots(figsize = (15,6))

for model_raw, label_ in zip(model_pool, label_pool):

    predictions = model_raw.predict([X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL])
    predictions_result = scaler_COST.inverse_transform(predictions)
    y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
    rmse = (predictions_result - y_test_COST_result)/y_test_COST_result
    plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction '+ label_)

plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Open Price")
plt.title('COST prediction')
plt.show()
plt.clf()

### plt different
plt.figure()
plt.subplots(figsize = (15,6))


for model_raw, label_ in zip(model_pool, label_pool):
    model_raw.summary()

    predictions = model_raw.predict([X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL])
    predictions_result = scaler_COST.inverse_transform(predictions)
    y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
    rmse = (predictions_result - y_test_COST_result)/y_test_COST_result
    
    X_Test_COST_result = scaler_COST.inverse_transform(X_test_COST[:,13])
    actual_move = (y_test_COST_result - X_Test_COST_result)/ X_Test_COST_result * 100

    plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper : 'label_)

plt.plot(df_v1.Date.values[num+time_step:], actual_move, label='Actual movement')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Different between actual and prediction")
plt.legend()
plt.show()
plt.clf()

# %%
core_model_v1 = lstm_sector_v1(timesteps = time_step, units_l1=64, units_l2=64
, X_train = [X1_train_COST, X1_train_KO, X1_train_Yr10, X1_train_DXY, X1_train_CPI, X1_train_WAL]
, y_train = y1_train_COST.flatten()
, X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
, y_val_data = y_test_COST.flatten())

# %%
core_model_v1.summary()

predictions = core_model_v1.predict([X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL])
predictions_result = scaler_COST.inverse_transform(predictions)
y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
rmse = (predictions_result - y_test_COST_result)/y_test_COST_result

# %%
plt.figure()
plt.subplots(figsize = (15,6))
plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Open Price")
plt.title('COST prediction')
plt.show()
plt.clf()

plt.figure()
plt.subplots(figsize = (15,6))
plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper')
plt.plot(df_v1.Date.values[num+time_step:], (y_test_COST_result/X_Test_COST_result)-1, label='Actual movement')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Different between actual and prediction")
plt.legend()
plt.show()
plt.clf()

# %%
def lstm_sector_c(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data, optimizer, batch_size, epoch):

    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    dense1 = Dense(25)(lstm2)
    output = Dense(1)(dense1)


    model = Model(inputs=[input1], outputs=output)

    return model

# %%
def lstm_sector_v1(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data):
    
    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    input2 = Input(shape=(timesteps, X_train[1].shape[-1]))
    lstm3 = LSTM(units_l1, return_sequences=True)(input2)
    lstm4 = LSTM(units_l2)(lstm3)
    
    input3 = Input(shape=(timesteps, X_train[2].shape[-1]))
    lstm5 = LSTM(units_l1, return_sequences=True)(input3)
    lstm6 = LSTM(units_l2)(lstm5)

    input4 = Input(shape=(timesteps, X_train[3].shape[-1]))
    lstm7 = LSTM(units_l1, return_sequences=True)(input4)
    lstm8 = LSTM(units_l2)(lstm7)

    input5 = Input(shape=(timesteps, X_train[4].shape[-1]))
    lstm9 = LSTM(units_l1, return_sequences=True)(input5)
    lstm10 = LSTM(units_l2)(lstm9)

    input6 = Input(shape=(timesteps, X_train[5].shape[-1]))
    lstm11 = LSTM(units_l1, return_sequences=True)(input6)
    lstm12 = LSTM(units_l2)(lstm11)

    concat = Concatenate()([lstm2, lstm4, lstm6, lstm8, lstm10, lstm12])
    dense1 = Dense(128, activation='relu')(concat)
    dense2 = Dense(32, activation='relu')(dense1)
    output = Dense(1, activation='relu')(dense2)


    model = Model(inputs=[input1, input2, input3, input4, input5, input6], outputs=output)

    return model

# %%
model_img_file = 'model.png'
tf.keras.utils.plot_model(lstm_sector_v1(timesteps = time_step, units_l1=64, units_l2=64
, X_train = [X1_train_COST, X1_train_KO, X1_train_Yr10, X1_train_DXY, X1_train_CPI, X1_train_WAL]
, y_train = y1_train_COST.flatten()
, X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
, y_val_data = y_test_COST.flatten()), to_file=model_img_file, 
                          show_shapes=True, 
                          show_layer_activations=True, 
                          show_dtype=True,
                          show_layer_names=True )
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.
