# %%
import pandas as pd
from keras.layers import Input, LSTM, Dense, Concatenate
from keras.models import Model
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

###plot
import numpy as np
import matplotlib.pyplot as plt

# %%
Train = pd.read_csv('WAL_MODEL_Train.csv')
Test = pd.read_csv('WAL_MODEL_Test.csv')
Valid = pd.read_csv('WAL_MODEL_Valid.csv')
COST_data = pd.read_csv('COST.csv')
KO_data = pd.read_csv('KO.csv')
PEP_data = pd.read_csv('PEP.csv')
PG_data = pd.read_csv('PG.csv')
NSRGY_data = pd.read_csv('NSRGY.csv')

# %%
df = pd.concat([Train,Test,Valid],ignore_index=True)
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')

# %%
for all_date in [COST_data, KO_data, PEP_data, PG_data, NSRGY_data]:
    all_date['Date'] = pd.to_datetime(all_date['Date'], format='%d/%m/%Y %H:%M:%S').dt.date

# %%
print(['COST', 'KO', 'PEP', 'PG', 'NSRGY']+df.columns[1:].to_list())
# Out:
# ['COST', 'KO', 'PEP', 'PG', 'NSRGY', 'Date', 'WAL_Close', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', 'PCE', 'GDP', 'DXY_Close', 'CRE', 'CPI', 'UNRATE']

# %%
prices = pd.concat([COST_data['Close'], KO_data['Close'], PEP_data['Close'], PG_data['Close'], NSRGY_data['Close']],axis=1, ignore_index=True)
df = pd.concat([prices, df], axis=1, names=['COST', 'KO', 'PEP', 'PG', 'NSRGY']+df.columns[1:].to_list())

# %%
df = df.rename(columns={0:'COST', 1: "KO", 2: "PEP", 3:"PG", 4:'NSRGY'})

# %%
df = df.drop(labels=['Unnamed: 0'], axis=1)

# %%
### number of nan
df.isnull().sum()
# Out:
# COST           1
# KO             1
# PEP            0
# PG             0
# NSRGY         60
# Date           0
# WAL_Close      0
# 6 Mo          44
# 1 Yr          44
# 2 Yr          44
# 3 Yr          44
# 5 Yr          44
# 7 Yr          44
# 10 Yr         44
# 20 Yr         44
# PCE            0
# GDP           63
# DXY_Close    114
# CRE            2
# CPI            0
# UNRATE         0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# COST           1
# KO             1
# PEP            0
# PG             0
# NSRGY         60
# Date           0
# WAL_Close      0
# 6 Mo          44
# 1 Yr          44
# 2 Yr          44
# 3 Yr          44
# 5 Yr          44
# 7 Yr          44
# 10 Yr         44
# 20 Yr         44
# PCE            0
# GDP           63
# DXY_Close    114
# CRE            2
# CPI            0
# UNRATE         0
# dtype: int64

# %%
### use pervious values
df = df.fillna(method='backfill')

# %%
df[df['Date'] < pd.to_datetime('2022-10-03')].isnull().sum()
# Out:
# COST         0
# KO           0
# PEP          0
# PG           0
# NSRGY        0
# Date         0
# WAL_Close    0
# 6 Mo         0
# 1 Yr         0
# 2 Yr         0
# 3 Yr         0
# 5 Yr         0
# 7 Yr         0
# 10 Yr        0
# 20 Yr        0
# PCE          0
# GDP          0
# DXY_Close    0
# CRE          0
# CPI          0
# UNRATE       0
# dtype: int64

# %%
df[df['Date'] < pd.to_datetime('2022-10-03')].to_csv('dataset.csv')

# %%
df_v1 = df[df['Date'] < pd.to_datetime('2022-10-03')]

# %%
df_v1['CPI'] = df_v1['CPI'].str[:3].astype(float)
# Out:
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\4047843882.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1['CPI'] = df_v1['CPI'].str[:3].astype(float)

# %%
list_df_v1 = df_v1.columns

# %%
WINDOW_SIZE = 3
for col in list_df_v1:
  for i in range(WINDOW_SIZE): # Shift values for each step in WINDOW_SIZE
      df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
df_v1.head()
# Out:
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
# C:\Users\Todd\AppData\Local\Temp\ipykernel_4732\3240552127.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_v1[f"{col} +{i+1}"] = df_v1[f"{col}"].shift(periods=i+1)
#     COST     KO    PEP     PG  NSRGY       Date  WAL_Close  6 Mo  1 Yr  2 Yr  \
# 0  44.50  28.13  36.88  52.93  18.35 2000-01-03      66.81  5.81  6.09  6.38
# 1  42.00  27.88  35.94  51.91  18.30 2000-01-04      64.38  5.75  6.00  6.30
# 2  42.78  28.47  35.06  50.83  18.00 2000-01-05      63.00  5.74  6.05  6.38
# 3  43.64  28.50  36.63  53.21  18.05 2000-01-06      63.69  5.69  6.03  6.35
# 4  46.50  30.31  38.50  57.53  18.75 2000-01-07      68.50  5.66  6.00  6.31
#
#    ...  DXY_Close +3  CRE +1  CRE +2  CRE +3  CPI +1  CPI +2  CPI +3  \
# 0  ...           NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1  ...           NaN    1.16     NaN     NaN     0.3     NaN     NaN
# 2  ...           NaN    1.16    1.16     NaN     0.3     0.3     NaN
# 3  ...    104.889999    1.18    1.16    1.16     0.3     0.3     0.3
# 4  ...    105.440002    1.18    1.18    1.16     0.3     0.3     0.3
#
#    UNRATE +1  UNRATE +2  UNRATE +3
# 0        NaN        NaN        NaN
# 1        4.0        NaN        NaN
# 2        3.8        4.0        NaN
# 3        4.0        3.8        4.0
# 4        4.0        4.0        3.8
#
# [5 rows x 84 columns]

# %%
scaler_COST = MinMaxScaler(feature_range = (0,1))
COST = scaler_COST.fit_transform(df_v1['COST'].to_numpy().reshape(-1, 1))
scaler = MinMaxScaler(feature_range = (0,1))
KO = scaler.fit_transform(df_v1['KO'].to_numpy().reshape(-1, 1))

scaler = MinMaxScaler(feature_range = (0,1))
Yr10 = scaler.fit_transform(df_v1['10 Yr'].to_numpy().reshape(-1, 1))
scaler = MinMaxScaler(feature_range = (0,1))
DXY = scaler.fit_transform(df_v1['DXY_Close'].to_numpy().reshape(-1, 1))

scaler = MinMaxScaler(feature_range = (0,1))
CPI = scaler.fit_transform(df_v1['CPI'].to_numpy().reshape(-1, 1))
scaler = MinMaxScaler(feature_range = (0,1))
WAL = scaler.fit_transform(df_v1['WAL_Close'].to_numpy().reshape(-1, 1))

# %%
length_data = len(df_v1)     # rows that data has
split_ratio = 1           # %70 train + %30 validation
length_train = round(length_data * split_ratio)  

X_train_COST = []
y_train_COST = []

X_train_KO = []
y_train_KO = []

X_train_Yr10 = []
y_train_Yr10 = []

X_train_DXY = []
y_train_DXY = []

X_train_CPI = []
y_train_CPI = []

X_train_WAL = []
y_train_WAL = []


time_step = 14

for i in range(time_step, length_train):
    X_train_COST.append(COST[i-time_step:i])
    y_train_COST.append(COST[i])
    
    X_train_KO.append(KO[i-time_step:i])
    y_train_KO.append(KO[i])

    X_train_Yr10.append(Yr10[i-time_step:i])
    y_train_Yr10.append(Yr10[i])
    
    X_train_DXY.append(DXY[i-time_step:i])
    y_train_DXY.append(DXY[i])
    
    X_train_CPI.append(CPI[i-time_step:i])
    y_train_CPI.append(CPI[i])

    X_train_WAL.append(WAL[i-time_step:i])
    y_train_WAL.append(WAL[i])

# %%
np.array(X_train_COST).shape
# Out:
# (5711, 14, 1)

# %%
# convert list to array
num = 4000
X1_train_COST, X1_train_KO, y1_train_COST, y1_train_KO = np.array(X_train_COST[:num]),np.array(X_train_KO[:num]), np.array(y_train_COST[:num]), np.array(y_train_KO[:num])
X1_train_Yr10, X1_train_DXY, y1_train_Yr10, y1_train_DXY = np.array(X_train_Yr10[:num]),np.array(X_train_DXY[:num]), np.array(y_train_Yr10[:num]), np.array(y_train_DXY[:num])
X1_train_CPI, X1_train_WAL, y1_train_CPI, y1_train_WAL = np.array(X_train_CPI[:num]),np.array(X_train_WAL[:num]), np.array(y_train_CPI[:num]), np.array(y_train_WAL[:num])


X_test_COST, y_test_COST, X_test_KO, y_test_KO = np.array(X_train_COST[num:]), np.array(y_train_COST[num:]), np.array(X_train_KO[num:]), np.array(y_train_KO[num:])
X_test_Yr10, y_test_Yr10, X_test_DXY, y_test_DXY = np.array(X_train_Yr10[num:]), np.array(y_train_Yr10[num:]), np.array(X_train_DXY[num:]), np.array(y_train_DXY[num:])
X_test_CPI, y_test_CPI, X_test_WAL, y_test_WAL = np.array(X_train_CPI[num:]), np.array(y_train_CPI[num:]), np.array(X_train_WAL[num:]), np.array(y_train_WAL[num:])

# %%
#X_train_COST[..., np.newaxis].shape

# %%
### PLOT graph
for tar in ['COST', 'KO', 'PEP', 'PG', 'NSRGY', 'WAL_Close', '6 Mo', '1 Yr', '2 Yr', '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', 'PCE', 'GDP',
       'DXY_Close', 'CRE', 'CPI', 'UNRATE']:
    plt.figure()
    plt.subplots(figsize = (15,6))
    plt.plot(df_v1.Date.values, df_v1[tar].values)
    plt.xlabel("Day1 to Day4051")
    plt.ylabel("Open Price")
    plt.title(tar+' values')
    plt.show()
    
    break

# %%
def lstm_sector(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data):

    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    input2 = Input(shape=(timesteps, X_train[1].shape[-1]))
    lstm3 = LSTM(units_l1, return_sequences=True)(input2)
    lstm4 = LSTM(units_l2)(lstm3)
    

    concat = Concatenate()([lstm2, lstm4])
    dense1 = Dense(16, activation='relu')(concat)
    output = Dense(1, activation='relu')(dense1)


    model = Model(inputs=[input1, input2], outputs=output)
    model.compile(loss='mean_squared_error', optimizer='adam', metrics = [tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

    # Train the model
    trained_model = model.fit(x=X_train, y=y_train, validation_data = (X_val_dataset, y_val_data), batch_size=16, epochs=10)

    return trained_model

def lstm_sector_c(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data, optimizer, batch_size, epoch):

    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    dense1 = Dense(25)(lstm2)
    output = Dense(1)(dense1)


    model = Model(inputs=[input1], outputs=output)
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics = [tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

    # Train the model
    core_model = model.fit(x=X_train, y=y_train, validation_data = (X_val_dataset, y_val_data), batch_size=batch_size, epochs=epoch)

    return core_model

# %%
learning_rate = [0.0005]
batch_size = [1, 8, 64, 128]
epochs = [10]
model_pool = []


for lr in learning_rate:
    optimizers = [tf.keras.optimizers.legacy.Adam(0.0005)]
    #optimizers = ['adam', 'SGD']
    for bs in batch_size:
        for epoch in epochs:
            for op in optimizers:
                model_pool.append(lstm_sector_c(timesteps = time_step, units_l1=64, units_l2=64
                , X_train = X1_train_COST
                , y_train = y1_train_COST.flatten()
                , X_val_dataset=X_test_COST
                , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
# Out:
# Epoch 1/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 5.1085e-05 - mean_squared_error: 5.1085e-05 - mean_absolute_error: 0.0047 - val_loss: 8.2836e-04 - val_mean_squared_error: 8.2836e-04 - val_mean_absolute_error: 0.0217
# Epoch 2/10
# 4000/4000 [==============================] - 18s 4ms/step - loss: 2.5364e-05 - mean_squared_error: 2.5364e-05 - mean_absolute_error: 0.0037 - val_loss: 7.8530e-04 - val_mean_squared_error: 7.8530e-04 - val_mean_absolute_error: 0.0230
# Epoch 3/10
# 4000/4000 [==============================] - 18s 4ms/step - loss: 1.9199e-05 - mean_squared_error: 1.9199e-05 - mean_absolute_error: 0.0033 - val_loss: 2.2661e-04 - val_mean_squared_error: 2.2661e-04 - val_mean_absolute_error: 0.0096
# Epoch 4/10
# 4000/4000 [==============================] - 18s 4ms/step - loss: 1.3786e-05 - mean_squared_error: 1.3786e-05 - mean_absolute_error: 0.0028 - val_loss: 1.9210e-04 - val_mean_squared_error: 1.9210e-04 - val_mean_absolute_error: 0.0085
# Epoch 5/10
# 4000/4000 [==============================] - 18s 4ms/step - loss: 1.2287e-05 - mean_squared_error: 1.2287e-05 - mean_absolute_error: 0.0026 - val_loss: 2.8360e-04 - val_mean_squared_error: 2.8360e-04 - val_mean_absolute_error: 0.0118
# Epoch 6/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.1590e-05 - mean_squared_error: 1.1590e-05 - mean_absolute_error: 0.0025 - val_loss: 1.2359e-04 - val_mean_squared_error: 1.2359e-04 - val_mean_absolute_error: 0.0076
# Epoch 7/10
# 4000/4000 [==============================] - 18s 4ms/step - loss: 1.0962e-05 - mean_squared_error: 1.0962e-05 - mean_absolute_error: 0.0025 - val_loss: 3.5548e-04 - val_mean_squared_error: 3.5548e-04 - val_mean_absolute_error: 0.0122
# Epoch 8/10
# 4000/4000 [==============================] - 18s 4ms/step - loss: 9.7481e-06 - mean_squared_error: 9.7481e-06 - mean_absolute_error: 0.0023 - val_loss: 4.3366e-04 - val_mean_squared_error: 4.3366e-04 - val_mean_absolute_error: 0.0146
# Epoch 9/10
# 4000/4000 [==============================] - 18s 5ms/step - loss: 9.9476e-06 - mean_squared_error: 9.9476e-06 - mean_absolute_error: 0.0024 - val_loss: 3.0358e-04 - val_mean_squared_error: 3.0358e-04 - val_mean_absolute_error: 0.0105
# Epoch 10/10
# 4000/4000 [==============================] - 16s 4ms/step - loss: 1.0276e-05 - mean_squared_error: 1.0276e-05 - mean_absolute_error: 0.0024 - val_loss: 3.4269e-04 - val_mean_squared_error: 3.4269e-04 - val_mean_absolute_error: 0.0108
# Epoch 1/10
# 500/500 [==============================] - 4s 5ms/step - loss: 6.1014e-05 - mean_squared_error: 6.1014e-05 - mean_absolute_error: 0.0041 - val_loss: 7.2198e-04 - val_mean_squared_error: 7.2198e-04 - val_mean_absolute_error: 0.0169
# Epoch 2/10
# 500/500 [==============================] - 2s 5ms/step - loss: 1.5219e-05 - mean_squared_error: 1.5219e-05 - mean_absolute_error: 0.0029 - val_loss: 5.1724e-04 - val_mean_squared_error: 5.1724e-04 - val_mean_absolute_error: 0.0140
# Epoch 3/10
# 500/500 [==============================] - 2s 5ms/step - loss: 1.4431e-05 - mean_squared_error: 1.4431e-05 - mean_absolute_error: 0.0028 - val_loss: 4.0055e-04 - val_mean_squared_error: 4.0055e-04 - val_mean_absolute_error: 0.0123
# Epoch 4/10
# 500/500 [==============================] - 2s 4ms/step - loss: 1.4228e-05 - mean_squared_error: 1.4228e-05 - mean_absolute_error: 0.0028 - val_loss: 2.4917e-04 - val_mean_squared_error: 2.4917e-04 - val_mean_absolute_error: 0.0103
# Epoch 5/10
# 500/500 [==============================] - 2s 4ms/step - loss: 1.2126e-05 - mean_squared_error: 1.2126e-05 - mean_absolute_error: 0.0026 - val_loss: 5.0570e-04 - val_mean_squared_error: 5.0570e-04 - val_mean_absolute_error: 0.0147
# Epoch 6/10
# 500/500 [==============================] - 2s 4ms/step - loss: 1.1173e-05 - mean_squared_error: 1.1173e-05 - mean_absolute_error: 0.0025 - val_loss: 2.4689e-04 - val_mean_squared_error: 2.4689e-04 - val_mean_absolute_error: 0.0099
# Epoch 7/10
# 500/500 [==============================] - 2s 5ms/step - loss: 1.0787e-05 - mean_squared_error: 1.0787e-05 - mean_absolute_error: 0.0025 - val_loss: 1.7645e-04 - val_mean_squared_error: 1.7645e-04 - val_mean_absolute_error: 0.0084
# Epoch 8/10
# 500/500 [==============================] - 2s 5ms/step - loss: 1.0646e-05 - mean_squared_error: 1.0646e-05 - mean_absolute_error: 0.0024 - val_loss: 1.8517e-04 - val_mean_squared_error: 1.8517e-04 - val_mean_absolute_error: 0.0086
# Epoch 9/10
# 500/500 [==============================] - 2s 5ms/step - loss: 9.1892e-06 - mean_squared_error: 9.1892e-06 - mean_absolute_error: 0.0023 - val_loss: 1.5351e-04 - val_mean_squared_error: 1.5351e-04 - val_mean_absolute_error: 0.0079
# Epoch 10/10
# 500/500 [==============================] - 3s 6ms/step - loss: 8.6718e-06 - mean_squared_error: 8.6718e-06 - mean_absolute_error: 0.0022 - val_loss: 1.7439e-04 - val_mean_squared_error: 1.7439e-04 - val_mean_absolute_error: 0.0099
# Epoch 1/10
# 63/63 [==============================] - 4s 30ms/step - loss: 3.5464e-04 - mean_squared_error: 3.5464e-04 - mean_absolute_error: 0.0109 - val_loss: 3.5708e-04 - val_mean_squared_error: 3.5708e-04 - val_mean_absolute_error: 0.0121
# Epoch 2/10
# 63/63 [==============================] - 1s 20ms/step - loss: 1.1563e-05 - mean_squared_error: 1.1563e-05 - mean_absolute_error: 0.0025 - val_loss: 3.3205e-04 - val_mean_squared_error: 3.3205e-04 - val_mean_absolute_error: 0.0118
# Epoch 3/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.1136e-05 - mean_squared_error: 1.1136e-05 - mean_absolute_error: 0.0024 - val_loss: 2.9577e-04 - val_mean_squared_error: 2.9577e-04 - val_mean_absolute_error: 0.0112
# Epoch 4/10
# 63/63 [==============================] - 1s 20ms/step - loss: 1.1155e-05 - mean_squared_error: 1.1155e-05 - mean_absolute_error: 0.0024 - val_loss: 3.1750e-04 - val_mean_squared_error: 3.1750e-04 - val_mean_absolute_error: 0.0115
# Epoch 5/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.1663e-05 - mean_squared_error: 1.1663e-05 - mean_absolute_error: 0.0025 - val_loss: 3.3138e-04 - val_mean_squared_error: 3.3138e-04 - val_mean_absolute_error: 0.0117
# Epoch 6/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.1076e-05 - mean_squared_error: 1.1076e-05 - mean_absolute_error: 0.0024 - val_loss: 2.9956e-04 - val_mean_squared_error: 2.9956e-04 - val_mean_absolute_error: 0.0112
# Epoch 7/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.0928e-05 - mean_squared_error: 1.0928e-05 - mean_absolute_error: 0.0024 - val_loss: 4.1579e-04 - val_mean_squared_error: 4.1579e-04 - val_mean_absolute_error: 0.0131
# Epoch 8/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.0921e-05 - mean_squared_error: 1.0921e-05 - mean_absolute_error: 0.0024 - val_loss: 3.6374e-04 - val_mean_squared_error: 3.6374e-04 - val_mean_absolute_error: 0.0121
# Epoch 9/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.0695e-05 - mean_squared_error: 1.0695e-05 - mean_absolute_error: 0.0024 - val_loss: 2.9519e-04 - val_mean_squared_error: 2.9519e-04 - val_mean_absolute_error: 0.0113
# Epoch 10/10
# 63/63 [==============================] - 1s 21ms/step - loss: 1.0910e-05 - mean_squared_error: 1.0910e-05 - mean_absolute_error: 0.0024 - val_loss: 3.3845e-04 - val_mean_squared_error: 3.3845e-04 - val_mean_absolute_error: 0.0117
# Epoch 1/10
# 32/32 [==============================] - 3s 41ms/step - loss: 7.7852e-04 - mean_squared_error: 7.7852e-04 - mean_absolute_error: 0.0178 - val_loss: 3.9975e-04 - val_mean_squared_error: 3.9975e-04 - val_mean_absolute_error: 0.0127
# Epoch 2/10
# 32/32 [==============================] - 1s 24ms/step - loss: 2.0300e-05 - mean_squared_error: 2.0300e-05 - mean_absolute_error: 0.0034 - val_loss: 5.4186e-04 - val_mean_squared_error: 5.4186e-04 - val_mean_absolute_error: 0.0145
# Epoch 3/10
# 32/32 [==============================] - 1s 25ms/step - loss: 1.1318e-05 - mean_squared_error: 1.1318e-05 - mean_absolute_error: 0.0025 - val_loss: 4.1968e-04 - val_mean_squared_error: 4.1968e-04 - val_mean_absolute_error: 0.0127
# Epoch 4/10
# 32/32 [==============================] - 1s 24ms/step - loss: 1.1276e-05 - mean_squared_error: 1.1276e-05 - mean_absolute_error: 0.0025 - val_loss: 2.9778e-04 - val_mean_squared_error: 2.9778e-04 - val_mean_absolute_error: 0.0108
# Epoch 5/10
# 32/32 [==============================] - 1s 24ms/step - loss: 1.1210e-05 - mean_squared_error: 1.1210e-05 - mean_absolute_error: 0.0024 - val_loss: 2.9384e-04 - val_mean_squared_error: 2.9384e-04 - val_mean_absolute_error: 0.0108
# Epoch 6/10
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1524e-05 - mean_squared_error: 1.1524e-05 - mean_absolute_error: 0.0025 - val_loss: 2.8406e-04 - val_mean_squared_error: 2.8406e-04 - val_mean_absolute_error: 0.0107
# Epoch 7/10
# 32/32 [==============================] - 1s 23ms/step - loss: 1.1131e-05 - mean_squared_error: 1.1131e-05 - mean_absolute_error: 0.0024 - val_loss: 2.7463e-04 - val_mean_squared_error: 2.7463e-04 - val_mean_absolute_error: 0.0106
# Epoch 8/10
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0723e-05 - mean_squared_error: 1.0723e-05 - mean_absolute_error: 0.0024 - val_loss: 2.7641e-04 - val_mean_squared_error: 2.7641e-04 - val_mean_absolute_error: 0.0108
# Epoch 9/10
# 32/32 [==============================] - 1s 25ms/step - loss: 1.0674e-05 - mean_squared_error: 1.0674e-05 - mean_absolute_error: 0.0024 - val_loss: 2.7099e-04 - val_mean_squared_error: 2.7099e-04 - val_mean_absolute_error: 0.0107
# Epoch 10/10
# 32/32 [==============================] - 1s 23ms/step - loss: 1.0375e-05 - mean_squared_error: 1.0375e-05 - mean_absolute_error: 0.0023 - val_loss: 2.7113e-04 - val_mean_squared_error: 2.7113e-04 - val_mean_absolute_error: 0.0107

# %%
learning_rate = [0.000005]
batch_size = [1, 8, 64, 128]
epochs = [10]
model_pool = []


for lr in learning_rate:
    optimizers = [tf.keras.optimizers.legacy.Adam(lr)]
    #optimizers = ['adam', 'SGD']
    for bs in batch_size:
        for epoch in epochs:
            for op in optimizers:
                model_pool.append(lstm_sector_c(timesteps = time_step, units_l1=64, units_l2=64
                , X_train = X1_train_COST
                , y_train = y1_train_COST.flatten()
                , X_val_dataset=X_test_COST
                , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
# Out:
# Epoch 1/10
# 4000/4000 [==============================] - 19s 4ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0255 - val_loss: 6.0112e-04 - val_mean_squared_error: 6.0112e-04 - val_mean_absolute_error: 0.0198
# Epoch 2/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.6592e-05 - mean_squared_error: 1.6592e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - val_mean_absolute_error: 0.0262
# Epoch 3/10
# 4000/4000 [==============================] - 19s 5ms/step - loss: 1.4437e-05 - mean_squared_error: 1.4437e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - val_mean_absolute_error: 0.0259
# Epoch 4/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.4177e-05 - mean_squared_error: 1.4177e-05 - mean_absolute_error: 0.0028 - val_loss: 0.0012 - val_mean_squared_error: 0.0012 - val_mean_absolute_error: 0.0223
# Epoch 5/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.3964e-05 - mean_squared_error: 1.3964e-05 - mean_absolute_error: 0.0027 - val_loss: 0.0011 - val_mean_squared_error: 0.0011 - val_mean_absolute_error: 0.0212
# Epoch 6/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.3795e-05 - mean_squared_error: 1.3795e-05 - mean_absolute_error: 0.0027 - val_loss: 7.2834e-04 - val_mean_squared_error: 7.2834e-04 - val_mean_absolute_error: 0.0162
# Epoch 7/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.3731e-05 - mean_squared_error: 1.3731e-05 - mean_absolute_error: 0.0027 - val_loss: 7.0397e-04 - val_mean_squared_error: 7.0397e-04 - val_mean_absolute_error: 0.0160
# Epoch 8/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.3575e-05 - mean_squared_error: 1.3575e-05 - mean_absolute_error: 0.0027 - val_loss: 7.0003e-04 - val_mean_squared_error: 7.0003e-04 - val_mean_absolute_error: 0.0162
# Epoch 9/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.3420e-05 - mean_squared_error: 1.3420e-05 - mean_absolute_error: 0.0027 - val_loss: 4.1382e-04 - val_mean_squared_error: 4.1382e-04 - val_mean_absolute_error: 0.0122
# Epoch 10/10
# 4000/4000 [==============================] - 17s 4ms/step - loss: 1.3098e-05 - mean_squared_error: 1.3098e-05 - mean_absolute_error: 0.0027 - val_loss: 6.0991e-04 - val_mean_squared_error: 6.0991e-04 - val_mean_absolute_error: 0.0154
# Epoch 1/10
# 500/500 [==============================] - 5s 7ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0344 - val_loss: 0.0382 - val_mean_squared_error: 0.0382 - val_mean_absolute_error: 0.1701
# Epoch 2/10
# 500/500 [==============================] - 3s 6ms/step - loss: 3.8300e-04 - mean_squared_error: 3.8300e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0394
# Epoch 3/10
# 500/500 [==============================] - 3s 7ms/step - loss: 4.2297e-05 - mean_squared_error: 4.2297e-05 - mean_absolute_error: 0.0050 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - val_mean_absolute_error: 0.0253
# Epoch 4/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6755e-05 - mean_squared_error: 1.6755e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0317
# Epoch 5/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6352e-05 - mean_squared_error: 1.6352e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0310
# Epoch 6/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6414e-05 - mean_squared_error: 1.6414e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - val_mean_absolute_error: 0.0321
# Epoch 7/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6337e-05 - mean_squared_error: 1.6337e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0315
# Epoch 8/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6291e-05 - mean_squared_error: 1.6291e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - val_mean_absolute_error: 0.0317
# Epoch 9/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6301e-05 - mean_squared_error: 1.6301e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0291
# Epoch 10/10
# 500/500 [==============================] - 3s 6ms/step - loss: 1.6358e-05 - mean_squared_error: 1.6358e-05 - mean_absolute_error: 0.0030 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - val_mean_absolute_error: 0.0286
# Epoch 1/10
# 63/63 [==============================] - 3s 21ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0433 - val_loss: 0.1142 - val_mean_squared_error: 0.1142 - val_mean_absolute_error: 0.2949
# Epoch 2/10
# 63/63 [==============================] - 1s 16ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0313 - val_loss: 0.0763 - val_mean_squared_error: 0.0763 - val_mean_absolute_error: 0.2379
# Epoch 3/10
# 63/63 [==============================] - 1s 15ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0290 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - val_mean_absolute_error: 0.2059
# Epoch 4/10
# 63/63 [==============================] - 1s 15ms/step - loss: 9.3978e-04 - mean_squared_error: 9.3978e-04 - mean_absolute_error: 0.0260 - val_loss: 0.0433 - val_mean_squared_error: 0.0433 - val_mean_absolute_error: 0.1789
# Epoch 5/10
# 63/63 [==============================] - 1s 15ms/step - loss: 7.1673e-04 - mean_squared_error: 7.1673e-04 - mean_absolute_error: 0.0227 - val_loss: 0.0313 - val_mean_squared_error: 0.0313 - val_mean_absolute_error: 0.1519
# Epoch 6/10
# 63/63 [==============================] - 1s 16ms/step - loss: 5.2835e-04 - mean_squared_error: 5.2835e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - val_mean_absolute_error: 0.1261
# Epoch 7/10
# 63/63 [==============================] - 1s 16ms/step - loss: 3.7363e-04 - mean_squared_error: 3.7363e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - val_mean_absolute_error: 0.1013
# Epoch 8/10
# 63/63 [==============================] - 1s 15ms/step - loss: 2.5306e-04 - mean_squared_error: 2.5306e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - val_mean_absolute_error: 0.0778
# Epoch 9/10
# 63/63 [==============================] - 1s 15ms/step - loss: 1.6359e-04 - mean_squared_error: 1.6359e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0573
# Epoch 10/10
# 63/63 [==============================] - 1s 14ms/step - loss: 1.0229e-04 - mean_squared_error: 1.0229e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - val_mean_absolute_error: 0.0396
# Epoch 1/10
# 32/32 [==============================] - 3s 37ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - mean_absolute_error: 0.0601 - val_loss: 0.2118 - val_mean_squared_error: 0.2118 - val_mean_absolute_error: 0.4090
# Epoch 2/10
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - mean_absolute_error: 0.0419 - val_loss: 0.1669 - val_mean_squared_error: 0.1669 - val_mean_absolute_error: 0.3592
# Epoch 3/10
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0377 - val_loss: 0.1395 - val_mean_squared_error: 0.1395 - val_mean_absolute_error: 0.3257
# Epoch 4/10
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0370 - val_loss: 0.1213 - val_mean_squared_error: 0.1213 - val_mean_absolute_error: 0.3023
# Epoch 5/10
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0366 - val_loss: 0.1085 - val_mean_squared_error: 0.1085 - val_mean_absolute_error: 0.2852
# Epoch 6/10
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0358 - val_loss: 0.0980 - val_mean_squared_error: 0.0980 - val_mean_absolute_error: 0.2707
# Epoch 7/10
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - mean_absolute_error: 0.0346 - val_loss: 0.0890 - val_mean_squared_error: 0.0890 - val_mean_absolute_error: 0.2578
# Epoch 8/10
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - mean_absolute_error: 0.0333 - val_loss: 0.0812 - val_mean_squared_error: 0.0812 - val_mean_absolute_error: 0.2463
# Epoch 9/10
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - mean_absolute_error: 0.0320 - val_loss: 0.0733 - val_mean_squared_error: 0.0733 - val_mean_absolute_error: 0.2340
# Epoch 10/10
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - mean_absolute_error: 0.0306 - val_loss: 0.0663 - val_mean_squared_error: 0.0663 - val_mean_absolute_error: 0.2227

# %%
len(batch_size)
# Out:
# 4

# %%
label_pool = []
for bs in batch_size:
            label_pool.append('Adam' +' with bs : ' +str(bs) + ' with lr : '+ str(lr))
            
for loss in ("loss", "val_loss"):
  for i in range(len(batch_size)):
    plt.plot(model_pool[i].history[loss], label='Adam' +' with bs : ' +str(batch_size[i]), linewidth =3)

  plt.grid()
  plt.xlabel("Epochs")
  plt.ylabel({"loss": "Training loss", "val_loss": "Validation loss"}[loss])
  plt.legend(loc="upper left")
  plt.show()

# %%
#core_model = lstm_sector_c(timesteps = time_step, units_l1=100, units_l2=100,X_train=X1_train_COST, y_train=y1_train_COST.flatten(), X_val_dataset=X_test_COST, y_val_data = y_test_COST.flatten())

# %%
#core_model.summary()

#predictions = core_model.predict(X_test_COST)
#predictions_result = scaler_COST.inverse_transform(predictions)
#y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
#X1_train_COST_result = scaler_COST.inverse_transform(X1_train_COST[:,0])
#X_Test_COST_result = scaler_COST.inverse_transform(X_test_COST[:,13])
#X1_train_COST
#rmse = (predictions_result - y_test_COST_result)/y_test_COST_result

# %%
#plt.figure()
#plt.subplots(figsize = (15,6))
#plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
#plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
#plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction')
#plt.legend()
#plt.xlabel("Time")
#plt.ylabel("Open Price")
#plt.title('COST prediction')
#plt.show()
#plt.clf()

#plt.figure()
#plt.subplots(figsize = (15,6))
#plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper')
#plt.plot(df_v1.Date.values[num+time_step:], (y_test_COST_result/X_Test_COST_result)-1, label='Actual movement')
#plt.xlabel("Time")
#plt.ylabel("Value")
#plt.title("Different between actual and prediction")
#plt.legend()
#plt.show()
#plt.clf()

# %%
#core_model = lstm_sector(timesteps = time_step, units_l1=32, units_l2=16,X_train=[X1_train_COST, 
#X1_train_KO], y_train=y1_train_COST, X_val_dataset=[X_test_COST, 
#X_test_KO], y_val_data = y_test_COST)

# %%
def lstm_sector_v1(timesteps, units_l1, units_l2, X_train, y_train, X_val_dataset, y_val_data, optimizer, batch_size, epoch):
    
    # Define the inputs for each LSTM
    input1 = Input(shape=(timesteps, X_train[0].shape[-1]))
    lstm1 = LSTM(units_l1, return_sequences=True)(input1)
    lstm2 = LSTM(units_l2)(lstm1)

    input2 = Input(shape=(timesteps, X_train[1].shape[-1]))
    lstm3 = LSTM(units_l1, return_sequences=True)(input2)
    lstm4 = LSTM(units_l2)(lstm3)
    
    input3 = Input(shape=(timesteps, X_train[2].shape[-1]))
    lstm5 = LSTM(units_l1, return_sequences=True)(input3)
    lstm6 = LSTM(units_l2)(lstm5)

    input4 = Input(shape=(timesteps, X_train[3].shape[-1]))
    lstm7 = LSTM(units_l1, return_sequences=True)(input4)
    lstm8 = LSTM(units_l2)(lstm7)

    input5 = Input(shape=(timesteps, X_train[4].shape[-1]))
    lstm9 = LSTM(units_l1, return_sequences=True)(input5)
    lstm10 = LSTM(units_l2)(lstm9)

    input6 = Input(shape=(timesteps, X_train[5].shape[-1]))
    lstm11 = LSTM(units_l1, return_sequences=True)(input6)
    lstm12 = LSTM(units_l2)(lstm11)

    concat = Concatenate()([lstm2, lstm4, lstm6, lstm8, lstm10, lstm12])
    dense1 = Dense(128, activation='relu')(concat)
    dense2 = Dense(32, activation='relu')(dense1)
    output = Dense(1, activation='relu')(dense2)


    model = Model(inputs=[input1, input2, input3, input4, input5, input6], outputs=output)
    model.compile(loss='mean_squared_error', optimizer=optimizer, metrics = [tf.keras.metrics.MeanSquaredError(), tf.keras.metrics.MeanAbsoluteError()])

    # Train the model
    model.fit(x=X_train, y=y_train, validation_data = (X_val_dataset, y_val_data), batch_size=batch_size, epochs=epoch)

    return model

# %%
learning_rate = [0.01]
batch_size = [64, 128]
epochs = [10]
model_pool = []


for lr in learning_rate:
    optimizers = [tf.keras.optimizers.Adam(lr), tf.keras.optimizers.SGD(lr), tf.keras.optimizers.Nadam(lr), tf.keras.optimizers.RMSprop(lr)]
    #optimizers = ['adam', 'SGD']
    for bs in batch_size:
        for epoch in epochs:
            for op in optimizers:
                model_pool.append(lstm_sector_c(timesteps = time_step, units_l1=64, units_l2=64
                , X_train = [X1_train_COST, X1_train_KO, X1_train_Yr10, X1_train_DXY, X1_train_CPI, X1_train_WAL]
                , y_train = y1_train_COST.flatten()
                , X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
                , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16404\2714097871.py in <module>
#      15                 , y_train = y1_train_COST.flatten()
#      16                 , X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
# ---> 17                 , y_val_data = y_test_COST.flatten(), optimizer = op, batch_size = bs, epoch = epoch))
#      18
#
# TypeError: lstm_sector_c() got an unexpected keyword argument 'optimizer'

# %%
label_pool = []
for opt in ['Adam', 'SGD', 'Nadam', 'RMSprop']:
    for bs in batch_size:
        label_pool.append(opt+' with batch_size : ' + str(bs))

# %%
label_pool
# Out:
# ['Adam with batch_size : 64',
#  'Adam with batch_size : 128',
#  'SGD with batch_size : 64',
#  'SGD with batch_size : 128',
#  'Nadam with batch_size : 64',
#  'Nadam with batch_size : 128',
#  'RMSprop with batch_size : 64',
#  'RMSprop with batch_size : 128']

# %%
label_pool = []
for opt in ['Adam', 'SGD', 'Nadam', 'RMSprop']:
    for bs in batch_size:
        label_pool.append(opt+' with batch_size : ' + str(bs))

plt.figure()
plt.subplots(figsize = (15,6))

for model_raw, label_ in zip(model_pool, label_pool):

    predictions = model_raw.predict([X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL])
    predictions_result = scaler_COST.inverse_transform(predictions)
    y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
    rmse = (predictions_result - y_test_COST_result)/y_test_COST_result
    plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction '+ label_)

plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Open Price")
plt.title('COST prediction')
plt.show()
plt.clf()

### plt different
plt.figure()
plt.subplots(figsize = (15,6))


for model_raw, label_ in zip(model_pool, label_pool):
    model_raw.summary()

    predictions = model_raw.predict([X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL])
    predictions_result = scaler_COST.inverse_transform(predictions)
    y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
    rmse = (predictions_result - y_test_COST_result)/y_test_COST_result
    
    X_Test_COST_result = scaler_COST.inverse_transform(X_test_COST[:,13])
    actual_move = (y_test_COST_result - X_Test_COST_result)/ X_Test_COST_result * 100

    plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper : '+label_)

plt.plot(df_v1.Date.values[num+time_step:], actual_move, label='Actual movement')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Different between actual and prediction")
plt.legend()
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21376\2709071364.py in <module>
#       1 label_pool = []
#       2 for opt in ['Adam', 'SGD', 'Nadam', 'RMSprop']:
# ----> 3     for bs in batch_size:
#       4         label_pool.append(opt+' with batch_size : ' + str(bs))
#       5
#
# NameError: name 'batch_size' is not defined

# %%
core_model_v1 = lstm_sector_v1(timesteps = time_step, units_l1=64, units_l2=64
, X_train = [X1_train_COST, X1_train_KO, X1_train_Yr10, X1_train_DXY, X1_train_CPI, X1_train_WAL]
, y_train = y1_train_COST.flatten()
, X_val_dataset=[X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL]
, y_val_data = y_test_COST.flatten(),optimizer='adam', batch_size=8, epoch=5)
# Out:
# Train on 4000 samples, validate on 1711 samples
# Epoch 1/5
# 4000/4000 [==============================] - 42s 11ms/step - loss: 1.2659e-04 - mean_squared_error: 3.7550e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0026 - val_mean_squared_error: 2.4357e-04 - val_mean_absolute_error: 0.0095
# Epoch 2/5
# 4000/4000 [==============================] - 43s 11ms/step - loss: 2.7896e-05 - mean_squared_error: 6.6359e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0045 - val_mean_squared_error: 5.6453e-04 - val_mean_absolute_error: 0.0111
# Epoch 3/5
# 4000/4000 [==============================] - 43s 11ms/step - loss: 3.3308e-05 - mean_squared_error: 9.6564e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0046 - val_mean_squared_error: 8.5079e-04 - val_mean_absolute_error: 0.0126
# Epoch 4/5
# 4000/4000 [==============================] - 65s 16ms/step - loss: 2.7147e-05 - mean_squared_error: 0.0011 - mean_absolute_error: 0.0142 - val_loss: 0.0056 - val_mean_squared_error: 0.0010 - val_mean_absolute_error: 0.0134
# Epoch 5/5
# 4000/4000 [==============================] - 58s 15ms/step - loss: 2.4876e-05 - mean_squared_error: 0.0012 - mean_absolute_error: 0.0148 - val_loss: 0.0034 - val_mean_squared_error: 0.0011 - val_mean_absolute_error: 0.0140

# %%
core_model_v1.summary()

predictions = core_model_v1.predict([X_test_COST, X_test_KO, X_test_Yr10, X_test_DXY, X_test_CPI, X_test_WAL])
predictions_result = scaler_COST.inverse_transform(predictions)
y_test_COST_result = scaler_COST.inverse_transform(y_test_COST)
rmse = (predictions_result - y_test_COST_result)/y_test_COST_result
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# input_14 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# input_15 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# input_17 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           (None, 14, 1)        0
# __________________________________________________________________________________________________
# lstm_25 (LSTM)                  (None, 14, 64)       16896       input_13[0][0]
# __________________________________________________________________________________________________
# lstm_27 (LSTM)                  (None, 14, 64)       16896       input_14[0][0]
# __________________________________________________________________________________________________
# lstm_29 (LSTM)                  (None, 14, 64)       16896       input_15[0][0]
# __________________________________________________________________________________________________
# lstm_31 (LSTM)                  (None, 14, 64)       16896       input_16[0][0]
# __________________________________________________________________________________________________
# lstm_33 (LSTM)                  (None, 14, 64)       16896       input_17[0][0]
# __________________________________________________________________________________________________
# lstm_35 (LSTM)                  (None, 14, 64)       16896       input_18[0][0]
# __________________________________________________________________________________________________
# lstm_26 (LSTM)                  (None, 64)           33024       lstm_25[0][0]
# __________________________________________________________________________________________________
# lstm_28 (LSTM)                  (None, 64)           33024       lstm_27[0][0]
# __________________________________________________________________________________________________
# lstm_30 (LSTM)                  (None, 64)           33024       lstm_29[0][0]
# __________________________________________________________________________________________________
# lstm_32 (LSTM)                  (None, 64)           33024       lstm_31[0][0]
# __________________________________________________________________________________________________
# lstm_34 (LSTM)                  (None, 64)           33024       lstm_33[0][0]
# __________________________________________________________________________________________________
# lstm_36 (LSTM)                  (None, 64)           33024       lstm_35[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 384)          0           lstm_26[0][0]
#                                                                  lstm_28[0][0]
#                                                                  lstm_30[0][0]
#                                                                  lstm_32[0][0]
#                                                                  lstm_34[0][0]
#                                                                  lstm_36[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          49280       concatenate_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 32)           4128        dense_7[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1)            33          dense_8[0][0]
# ==================================================================================================
# Total params: 352,961
# Trainable params: 352,961
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plt.figure()
plt.subplots(figsize = (15,6))
plt.plot(df_v1.Date.values[:num+time_step], df_v1['COST'].values[:num+time_step], 'black',label='Train_actual')
plt.plot(df_v1.Date.values[num+time_step:],y_test_COST_result, 'ro', markersize=1, label='Test_actual')
plt.plot(df_v1.Date.values[num+time_step:],predictions_result, label='Prediction')
plt.legend()
plt.xlabel("Time")
plt.ylabel("Open Price")
plt.title('COST prediction')
plt.show()
plt.clf()

plt.figure()
plt.subplots(figsize = (15,6))
plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper')
plt.plot(df_v1.Date.values[num+time_step:], (y_test_COST_result/X_Test_COST_result)-1, label='Actual movement')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("Different between actual and prediction")
plt.legend()
plt.show()
plt.clf()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21376\2487118513.py in <module>
#      14 plt.subplots(figsize = (15,6))
#      15 plt.plot(df_v1.Date.values[num+time_step:], rmse, label='Hyper')
# ---> 16 plt.plot(df_v1.Date.values[num+time_step:], (y_test_COST_result/X_Test_COST_result)-1, label='Actual movement')
#      17 plt.xlabel("Time")
#      18 plt.ylabel("Value")
#
# NameError: name 'X_Test_COST_result' is not defined
